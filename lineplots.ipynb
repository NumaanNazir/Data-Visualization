# %%
#Lineplot 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

#LOADING A DATA SET 
data=pd.read_csv("C:\\Users\\nqnqa\\Downloads\\Churn_Modelling.csv")

#PANDAS
data01=data.sample(10).plot.line(x="Balance",y="CreditScore" )
plt.show()

# %%
#MATPLOTLIB
plt.plot([2,4,6,8,10],[1,3,5,7,4])
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
#Seaborn
sns.lineplot(data, x="Age",y="CreditScore")
# Out:
# <Axes: xlabel='Age', ylabel='CreditScore'>
