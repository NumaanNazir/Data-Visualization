# %% [markdown]
#                                                      LINE PLOTS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#LOAD A DATA SET OF CHURN MODELLING

x=pd.read_csv("C:\\Users\\nqnqa\\Downloads\\Churn_Modelling.csv")

print(x.shape)
x.columns
# Out:
# (10000, 14)
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
#LINE PLOT WITH PANDAS
x.plot.line(x="Gender", y="Balance")
# Out:
# <Axes: xlabel='Gender'>

# %%
#LINE PLOT WITH MATPLOTLIB
plt.plot(x["Age"],x["Balance"])

# %%
#LINE PLOT WITH SEABORN
sns.lineplot(data=x , x="Age", y="IsActiveMember")
# Out:
# <Axes: xlabel='Age', ylabel='IsActiveMember'>
